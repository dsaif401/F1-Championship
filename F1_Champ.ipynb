# %%
import pandas as pd
import numpy as np

# %%
result_df = pd.read_csv("D:\\Data_Science\\Datasets\\F1_For\\results_1.csv")
stats_df = pd.read_csv("D:\\Data_Science\\Datasets\\F1_For\\status.csv")
drivers_df = pd.read_csv("D:\\Data_Science\\Datasets\\F1_For\\drivers.csv")
races_df = pd.read_csv("D:\\Data_Science\\Datasets\\F1_For\\races.csv")
constructor_df = pd.read_csv("D:\\Data_Science\\Datasets\\F1_For\\constructors.csv")
driver_standings_df = pd.read_csv("D:\\Data_Science\\Datasets\\F1_For\\driver_standings.csv")

# %%
pd.get_option("display.max_columns",None)
# Out:
# 20

# %%
result_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
stats_df.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
drivers_df.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
constructor_df.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
driver_standings_df.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
con1 = pd.merge(result_df, races_df, on ='raceId')
con2 = pd.merge(con1, drivers_df, on = 'driverId')
con3 = pd.merge(con2, driver_standings_df, on = 'driverId')
con4 = pd.merge(con3, constructor_df, on ='constructorId')
df = pd.merge(con4, stats_df, on ='statusId')
pd.get_option("display.max_columns",None)
df.head()
# Out:
#    resultId  raceId_x  driverId  constructorId number_x  grid position_x  \
# 0         1        18         1              1       22     1          1
# 1         1        18         1              1       22     1          1
# 2         1        18         1              1       22     1          1
# 3         1        18         1              1       22     1          1
# 4         1        18         1              1       22     1          1
#
#   positionText_x  positionOrder  points_x  ...  raceId_y points_y position_y  \
# 0              1              1      10.0  ...        18     10.0          1
# 1              1              1      10.0  ...        19     14.0          1
# 2              1              1      10.0  ...        20     14.0          3
# 3              1              1      10.0  ...        21     20.0          2
# 4              1              1      10.0  ...        22     28.0          3
#
#   positionText_y wins constructorRef   name_y  nationality_y  \
# 0              1    1        mclaren  McLaren        British
# 1              1    1        mclaren  McLaren        British
# 2              3    1        mclaren  McLaren        British
# 3              2    1        mclaren  McLaren        British
# 4              3    1        mclaren  McLaren        British
#
#                                     url    status
# 0  http://en.wikipedia.org/wiki/McLaren  Finished
# 1  http://en.wikipedia.org/wiki/McLaren  Finished
# 2  http://en.wikipedia.org/wiki/McLaren  Finished
# 3  http://en.wikipedia.org/wiki/McLaren  Finished
# 4  http://en.wikipedia.org/wiki/McLaren  Finished
#
# [5 rows x 44 columns]

# %%
df.isna().sum()
# Out:
# resultId             0
# raceId_x             0
# driverId             0
# constructorId        0
# number_x             0
# grid                 0
# position_x           0
# positionText_x       0
# positionOrder        0
# points_x             0
# laps                 0
# time_x               0
# milliseconds         0
# fastestLap           0
# rank                 0
# fastestLapTime       0
# fastestLapSpeed      0
# statusId             0
# year                 0
# round                0
# circuitId            0
# name_x               0
# date                 0
# time_y               0
# url_x                0
# driverRef            0
# number_y             0
# code                 0
# forename             0
# surname              0
# dob                  0
# nationality_x        0
# url_y                0
# driverStandingsId    0
# raceId_y             0
# points_y             0
# position_y           0
# positionText_y       0
# wins                 0
# constructorRef       0
# name_y               0
# nationality_y        0
# url                  0
# status               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3348650 entries, 0 to 3348649
# Data columns (total 44 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   resultId           int64
#  1   raceId_x           int64
#  2   driverId           int64
#  3   constructorId      int64
#  4   number_x           object
#  5   grid               int64
#  6   position_x         object
#  7   positionText_x     object
#  8   positionOrder      int64
#  9   points_x           float64
#  10  laps               int64
#  11  time_x             object
#  12  milliseconds       object
#  13  fastestLap         object
#  14  rank               object
#  15  fastestLapTime     object
#  16  fastestLapSpeed    object
#  17  statusId           int64
#  18  year               int64
#  19  round              int64
#  20  circuitId          int64
#  21  name_x             object
#  22  date               object
#  23  time_y             object
#  24  url_x              object
#  25  driverRef          object
#  26  number_y           object
#  27  code               object
#  28  forename           object
#  29  surname            object
#  30  dob                object
#  31  nationality_x      object
#  32  url_y              object
#  33  driverStandingsId  int64
#  34  raceId_y           int64
#  35  points_y           float64
#  36  position_y         int64
#  37  positionText_y     object
#  38  wins               int64
#  39  constructorRef     object
#  40  name_y             object
#  41  nationality_y      object
#  42  url                object
#  43  status             object
# dtypes: float64(2), int64(15), object(27)
# memory usage: 1.1+ GB

# %%
# summary
df.describe().T
# Out:
#                        count          mean           std     min      25%  \
# resultId           3348650.0  12007.688474   7901.419969     1.0   4814.0
# raceId_x           3348650.0    490.572793    315.901639     1.0    223.0
# driverId           3348650.0    183.326989    241.487947     1.0     20.0
# constructorId      3348650.0     37.409320     54.292359     1.0      6.0
# grid               3348650.0      9.811387      6.601276     0.0      4.0
# positionOrder      3348650.0     11.336113      7.437479     1.0      5.0
# points_x           3348650.0      2.810254      5.112221     0.0      0.0
# laps               3348650.0     48.012672     25.461189     0.0     31.0
# statusId           3348650.0     13.494156     22.501670     1.0      1.0
# year               3348650.0   1995.139344     16.882719  1950.0   1983.0
# round              3348650.0      8.790904      5.046594     1.0      5.0
# circuitId          3348650.0     20.665615     16.513504     1.0      9.0
# driverStandingsId  3348650.0  37092.706830  25017.848114     1.0  12847.0
# raceId_y           3348650.0    493.092876    316.441235     1.0    227.0
# points_y           3348650.0     26.358127     49.342845     0.0      0.0
# position_y         3348650.0     11.795097      9.262277     1.0      5.0
# wins               3348650.0      0.544334      1.423867     0.0      0.0
#
#                        50%      75%      max
# resultId           11080.0  20391.0  25404.0
# raceId_x             445.0    775.0   1073.0
# driverId             102.0    207.0    854.0
# constructorId         17.0     35.0    214.0
# grid                   9.0     15.0     34.0
# positionOrder         10.0     17.0     39.0
# points_x               0.0      4.0     50.0
# laps                  54.0     67.0    200.0
# statusId               5.0     12.0    139.0
# year                1997.0   2010.0   2021.0
# round                  8.0     13.0     22.0
# circuitId             16.0     29.0     78.0
# driverStandingsId  22931.0  64450.0  70779.0
# raceId_y             448.0    782.0   1074.0
# points_y               7.0     28.0    413.0
# position_y            10.0     17.0    108.0
# wins                   0.0      0.0     13.0

# %%
df.columns
# Out:
# Index(['resultId', 'raceId_x', 'driverId', 'constructorId', 'number_x', 'grid',
#        'position_x', 'positionText_x', 'positionOrder', 'points_x', 'laps',
#        'time_x', 'milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId', 'year', 'round', 'circuitId', 'name_x',
#        'date', 'time_y', 'url_x', 'driverRef', 'number_y', 'code', 'forename',
#        'surname', 'dob', 'nationality_x', 'url_y', 'driverStandingsId',
#        'raceId_y', 'points_y', 'position_y', 'positionText_y', 'wins',
#        'constructorRef', 'name_y', 'nationality_y', 'url', 'status'],
#       dtype='object')

# %%
df = df.drop(['url','url_x','position_x','fastestLapTime','positionText_x','time_x','time_y','driverRef',
              'constructorRef','nationality_y','url_y','positionText_y','raceId_y','points_y'],1)

# %%
col_name = {'number_x':'number','milliseconds':'timetaken_in_millisec','fastestLapSpeed':'max_speed',
 'name_x':'grand_prix','number_y':'driver_num','code':'driver_code','nationality_x':'nationality','name_y':'company',
 'raceId_x':'racerId','points_x':'points','position_y':'position'}

# %%
df.rename(columns=col_name,inplace=True)
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid  positionOrder  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    points  laps timetaken_in_millisec  ... driver_code forename   surname  \
# 0    10.0    58               5690616  ...         HAM    Lewis  Hamilton
# 1    10.0    58               5690616  ...         HAM    Lewis  Hamilton
# 2    10.0    58               5690616  ...         HAM    Lewis  Hamilton
# 3    10.0    58               5690616  ...         HAM    Lewis  Hamilton
# 4    10.0    58               5690616  ...         HAM    Lewis  Hamilton
#
#           dob  nationality  driverStandingsId  position wins  company  \
# 0  1985-01-07      British                  1         1    1  McLaren
# 1  1985-01-07      British                  9         1    1  McLaren
# 2  1985-01-07      British                 27         3    1  McLaren
# 3  1985-01-07      British                 48         2    1  McLaren
# 4  1985-01-07      British                 69         3    1  McLaren
#
#      status
# 0  Finished
# 1  Finished
# 2  Finished
# 3  Finished
# 4  Finished
#
# [5 rows x 30 columns]

# %%
df['driver_name'] = df['forename']+' '+df['surname']

# %%
df = df.drop(['forename','surname'],1)

# %%
pd.to_datetime(df.date)
# Out:
# 0         2008-03-16
# 1         2008-03-16
# 2         2008-03-16
# 3         2008-03-16
# 4         2008-03-16
#              ...
# 3348645   1951-05-30
# 3348646   1951-05-30
# 3348647   1951-05-30
# 3348648   1951-05-30
# 3348649   1951-05-30
# Name: date, Length: 3348650, dtype: datetime64[ns]

# %%
df.shape
# Out:
# (3348650, 29)

# %%
df['dob'] = pd.to_datetime(df['dob'])
df['date'] = pd.to_datetime(df['date'])

# %%
from datetime import datetime

# %%
dates = datetime.today()-df['dob']
age = dates.dt.days/365

# %%
df['age'] = round(age)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    resultId  racerId  driverId  constructorId number  grid  positionOrder  \
# 0         1       18         1              1     22     1              1
# 1         1       18         1              1     22     1              1
# 2         1       18         1              1     22     1              1
# 3         1       18         1              1     22     1              1
# 4         1       18         1              1     22     1              1
#
#    points  laps timetaken_in_millisec fastestLap rank max_speed  statusId  \
# 0    10.0    58               5690616         39    2   218.300         1
# 1    10.0    58               5690616         39    2   218.300         1
# 2    10.0    58               5690616         39    2   218.300         1
# 3    10.0    58               5690616         39    2   218.300         1
# 4    10.0    58               5690616         39    2   218.300         1
#
#    year  round  circuitId             grand_prix       date driver_num  \
# 0  2008      1          1  Australian Grand Prix 2008-03-16         44
# 1  2008      1          1  Australian Grand Prix 2008-03-16         44
# 2  2008      1          1  Australian Grand Prix 2008-03-16         44
# 3  2008      1          1  Australian Grand Prix 2008-03-16         44
# 4  2008      1          1  Australian Grand Prix 2008-03-16         44
#
#   driver_code        dob nationality  driverStandingsId  position  wins  \
# 0         HAM 1985-01-07     British                  1         1     1
# 1         HAM 1985-01-07     British                  9         1     1
# 2         HAM 1985-01-07     British                 27         3     1
# 3         HAM 1985-01-07     British                 48         2     1
# 4         HAM 1985-01-07     British                 69         3     1
#
#    company    status     driver_name   age
# 0  McLaren  Finished  Lewis Hamilton  37.0
# 1  McLaren  Finished  Lewis Hamilton  37.0
# 2  McLaren  Finished  Lewis Hamilton  37.0
# 3  McLaren  Finished  Lewis Hamilton  37.0
# 4  McLaren  Finished  Lewis Hamilton  37.0

# %%
l = ['number','timetaken_in_millisec','fastestLap','rank','max_speed','driver_num']
for i in l:
    df[i] = pd.to_numeric(df[i],errors='coerce')

# %%
df.drop('driver_num',1,inplace=True)

# %%
cat = []
num = []
for i in df.columns:
    if df[i].dtypes == 'O':
        cat.append(i)
    else:
        num.append(i)

# %%
df[cat].head()
# Out:
#               grand_prix driver_code nationality  company    status  \
# 0  Australian Grand Prix         HAM     British  McLaren  Finished
# 1  Australian Grand Prix         HAM     British  McLaren  Finished
# 2  Australian Grand Prix         HAM     British  McLaren  Finished
# 3  Australian Grand Prix         HAM     British  McLaren  Finished
# 4  Australian Grand Prix         HAM     British  McLaren  Finished
#
#       driver_name
# 0  Lewis Hamilton
# 1  Lewis Hamilton
# 2  Lewis Hamilton
# 3  Lewis Hamilton
# 4  Lewis Hamilton

# %%
df[num].head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid  positionOrder  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    points  laps  timetaken_in_millisec  fastestLap  rank  max_speed  statusId  \
# 0    10.0    58              5690616.0        39.0   2.0      218.3         1
# 1    10.0    58              5690616.0        39.0   2.0      218.3         1
# 2    10.0    58              5690616.0        39.0   2.0      218.3         1
# 3    10.0    58              5690616.0        39.0   2.0      218.3         1
# 4    10.0    58              5690616.0        39.0   2.0      218.3         1
#
#    year  round  circuitId       date        dob  driverStandingsId  position  \
# 0  2008      1          1 2008-03-16 1985-01-07                  1         1
# 1  2008      1          1 2008-03-16 1985-01-07                  9         1
# 2  2008      1          1 2008-03-16 1985-01-07                 27         3
# 3  2008      1          1 2008-03-16 1985-01-07                 48         2
# 4  2008      1          1 2008-03-16 1985-01-07                 69         3
#
#    wins   age
# 0     1  37.0
# 1     1  37.0
# 2     1  37.0
# 3     1  37.0
# 4     1  37.0

# %%
df.dtypes
# Out:
# resultId                          int64
# racerId                           int64
# driverId                          int64
# constructorId                     int64
# number                          float64
# grid                              int64
# positionOrder                     int64
# points                          float64
# laps                              int64
# timetaken_in_millisec           float64
# fastestLap                      float64
# rank                            float64
# max_speed                       float64
# statusId                          int64
# year                              int64
# round                             int64
# circuitId                         int64
# grand_prix                       object
# date                     datetime64[ns]
# driver_code                      object
# dob                      datetime64[ns]
# nationality                      object
# driverStandingsId                 int64
# position                          int64
# wins                              int64
# company                          object
# status                           object
# driver_name                      object
# age                             float64
# dtype: object

# %%
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid  positionOrder  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    points  laps  timetaken_in_millisec  fastestLap  rank  max_speed  statusId  \
# 0    10.0    58              5690616.0        39.0   2.0      218.3         1
# 1    10.0    58              5690616.0        39.0   2.0      218.3         1
# 2    10.0    58              5690616.0        39.0   2.0      218.3         1
# 3    10.0    58              5690616.0        39.0   2.0      218.3         1
# 4    10.0    58              5690616.0        39.0   2.0      218.3         1
#
#    year  round  circuitId             grand_prix       date driver_code  \
# 0  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 1  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 2  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 3  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 4  2008      1          1  Australian Grand Prix 2008-03-16         HAM
#
#          dob nationality  driverStandingsId  position  wins  company  \
# 0 1985-01-07     British                  1         1     1  McLaren
# 1 1985-01-07     British                  9         1     1  McLaren
# 2 1985-01-07     British                 27         3     1  McLaren
# 3 1985-01-07     British                 48         2     1  McLaren
# 4 1985-01-07     British                 69         3     1  McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  37.0
# 1  Finished  Lewis Hamilton  37.0
# 2  Finished  Lewis Hamilton  37.0
# 3  Finished  Lewis Hamilton  37.0
# 4  Finished  Lewis Hamilton  37.0

# %%
df.isnull().sum() / len(df) * 100
# Out:
# resultId                  0.000000
# racerId                   0.000000
# driverId                  0.000000
# constructorId             0.000000
# number                    0.004778
# grid                      0.000000
# positionOrder             0.000000
# points                    0.000000
# laps                      0.000000
# timetaken_in_millisec    62.912039
# fastestLap               63.678706
# rank                     62.794858
# max_speed                63.678706
# statusId                  0.000000
# year                      0.000000
# round                     0.000000
# circuitId                 0.000000
# grand_prix                0.000000
# date                      0.000000
# driver_code               0.000000
# dob                       0.000000
# nationality               0.000000
# driverStandingsId         0.000000
# position                  0.000000
# wins                      0.000000
# company                   0.000000
# status                    0.000000
# driver_name               0.000000
# age                       0.000000
# dtype: float64

# %%
df['max_speed'].mean()
# Out:
# 203.57074483026804

# %%
df[['rank','fastestLap']] = df[['rank','fastestLap']].fillna(0)
df['timetaken_in_millisec'] = df['timetaken_in_millisec'].fillna(df['timetaken_in_millisec'].mean())
df['max_speed']= df['max_speed'].fillna(df['max_speed'].mean())
df['number'] = df['number'].fillna(0)

# %%
df.isnull().sum() / len(df) * 100
# Out:
# resultId                 0.0
# racerId                  0.0
# driverId                 0.0
# constructorId            0.0
# number                   0.0
# grid                     0.0
# positionOrder            0.0
# points                   0.0
# laps                     0.0
# timetaken_in_millisec    0.0
# fastestLap               0.0
# rank                     0.0
# max_speed                0.0
# statusId                 0.0
# year                     0.0
# round                    0.0
# circuitId                0.0
# grand_prix               0.0
# date                     0.0
# driver_code              0.0
# dob                      0.0
# nationality              0.0
# driverStandingsId        0.0
# position                 0.0
# wins                     0.0
# company                  0.0
# status                   0.0
# driver_name              0.0
# age                      0.0
# dtype: float64

# %%
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid  positionOrder  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    points  laps  timetaken_in_millisec  fastestLap  rank  max_speed  statusId  \
# 0    10.0    58              5690616.0        39.0   2.0      218.3         1
# 1    10.0    58              5690616.0        39.0   2.0      218.3         1
# 2    10.0    58              5690616.0        39.0   2.0      218.3         1
# 3    10.0    58              5690616.0        39.0   2.0      218.3         1
# 4    10.0    58              5690616.0        39.0   2.0      218.3         1
#
#    year  round  circuitId             grand_prix       date driver_code  \
# 0  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 1  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 2  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 3  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 4  2008      1          1  Australian Grand Prix 2008-03-16         HAM
#
#          dob nationality  driverStandingsId  position  wins  company  \
# 0 1985-01-07     British                  1         1     1  McLaren
# 1 1985-01-07     British                  9         1     1  McLaren
# 2 1985-01-07     British                 27         3     1  McLaren
# 3 1985-01-07     British                 48         2     1  McLaren
# 4 1985-01-07     British                 69         3     1  McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  37.0
# 1  Finished  Lewis Hamilton  37.0
# 2  Finished  Lewis Hamilton  37.0
# 3  Finished  Lewis Hamilton  37.0
# 4  Finished  Lewis Hamilton  37.0

# %%
df.describe().T
# Out:
#                            count          mean            std        min  \
# resultId               3348650.0  1.200769e+04    7901.419969       1.00
# racerId                3348650.0  4.905728e+02     315.901639       1.00
# driverId               3348650.0  1.833270e+02     241.487947       1.00
# constructorId          3348650.0  3.740932e+01      54.292359       1.00
# number                 3348650.0  1.490537e+01      13.265392       0.00
# grid                   3348650.0  9.811387e+00       6.601276       0.00
# positionOrder          3348650.0  1.133611e+01       7.437479       1.00
# points                 3348650.0  2.810254e+00       5.112221       0.00
# laps                   3348650.0  4.801267e+01      25.461189       0.00
# timetaken_in_millisec  3348650.0  5.952802e+06  742532.014494  207071.00
# fastestLap             3348650.0  1.541696e+01      22.803800       0.00
# rank                   3348650.0  3.327844e+00       5.612978       0.00
# max_speed              3348650.0  2.035707e+02      12.800545      89.54
# statusId               3348650.0  1.349416e+01      22.501670       1.00
# year                   3348650.0  1.995139e+03      16.882719    1950.00
# round                  3348650.0  8.790904e+00       5.046594       1.00
# circuitId              3348650.0  2.066562e+01      16.513504       1.00
# driverStandingsId      3348650.0  3.709271e+04   25017.848114       1.00
# position               3348650.0  1.179510e+01       9.262277       1.00
# wins                   3348650.0  5.443343e-01       1.423867       0.00
# age                    3348650.0  5.700196e+01      18.418976      22.00
#
#                                 25%           50%           75%          max
# resultId               4.814000e+03  1.108000e+04  2.039100e+04     25404.00
# racerId                2.230000e+02  4.450000e+02  7.750000e+02      1073.00
# driverId               2.000000e+01  1.020000e+02  2.070000e+02       854.00
# constructorId          6.000000e+00  1.700000e+01  3.500000e+01       214.00
# number                 6.000000e+00  1.100000e+01  2.100000e+01       208.00
# grid                   4.000000e+00  9.000000e+00  1.500000e+01        34.00
# positionOrder          5.000000e+00  1.000000e+01  1.700000e+01        39.00
# points                 0.000000e+00  0.000000e+00  4.000000e+00        50.00
# laps                   3.100000e+01  5.400000e+01  6.700000e+01       200.00
# timetaken_in_millisec  5.952802e+06  5.952802e+06  5.952802e+06  15090540.00
# fastestLap             0.000000e+00  0.000000e+00  3.700000e+01        85.00
# rank                   0.000000e+00  0.000000e+00  5.000000e+00        24.00
# max_speed              2.035707e+02  2.035707e+02  2.035707e+02       257.32
# statusId               1.000000e+00  5.000000e+00  1.200000e+01       139.00
# year                   1.983000e+03  1.997000e+03  2.010000e+03      2021.00
# round                  5.000000e+00  8.000000e+00  1.300000e+01        22.00
# circuitId              9.000000e+00  1.600000e+01  2.900000e+01        78.00
# driverStandingsId      1.284700e+04  2.293100e+04  6.445000e+04     70779.00
# position               5.000000e+00  1.000000e+01  1.700000e+01       108.00
# wins                   0.000000e+00  0.000000e+00  0.000000e+00        13.00
# age                    4.200000e+01  5.400000e+01  7.000000e+01       125.00

# %%
circuit_df = pd.read_csv("D:\\Data_Science\\Datasets\\F1_For\\circuits.csv")
circuit_df.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4         http://en.wikipedia.org/wiki/Istanbul_Park

# %%
import folium
coordinates=[]
for lat,lng in zip(circuit_df['lat'],circuit_df['lng']):
    coordinates.append([lat,lng])
maps = folium.Map(zoom_start=2,tiles='Stamen Watercolor')  #map_types (Stamen Terrain, Stamen Toner, Mapbox Bright, cartodbpositron)
for i,j in zip(coordinates,circuit_df.name):
    marker = folium.Marker(
        location=i,
        icon=folium.Icon(icon="star",color='cadetblue'),
        popup="<strong>{0}</strong>".format(j))  #strong is used to bold the font (optional)
    marker.add_to(maps)
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a44d4aad0c332e191226777d5fc50f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a44d4aad0c332e191226777d5fc50f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8a44d4aad0c332e191226777d5fc50f1 = L.map(
#                 &quot;map_8a44d4aad0c332e191226777d5fc50f1&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30f0c121ce82ffecae2db8bc9a5a2b5e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a44d4aad0c332e191226777d5fc50f1);
#
#
#             var marker_3dcb0578003d597e525e233588c7aae9 = L.marker(
#                 [-37.8497, 144.968],
#                 {}
#             ).addTo(map_8a44d4aad0c332e191226777d5fc50f1);
#
#
#             var icon_9a320c7ef79eb8209a6c8ae0c04620f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3dcb0578003d597e525e233588c7aae9.setIcon(icon_9a320c7ef79eb8209a6c8ae0c04620f8);
#
#
#         var popup_1d379d30215d42dd4679b544ff775a4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_95fe3d2fa4ba0066eb1e330ade620603 = $(`&lt;div id=&quot;html_95fe3d2fa4ba0066eb1e330ade620603&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Albert Park Grand Prix Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_1d379d30215d42dd4679b544ff775a4e.setContent(html_95fe3d2fa4ba0066eb1e330ade620603);
#
#
#         marker_3dcb0578003d597e525e233588c7aae9.bindPopup(popup_1d379d30215d42dd4679b544ff775a4e)
#         ;
#
#
#
#
#             var marker_efd0d22d3f54ef7e87f4a711402d7ce7 = L.marker(
#                 [2.76083, 101.738],
#                 {}
#             ).addTo(map_8a44d4aad0c332e191226777d5fc50f1);
#
#
#             var icon_5cb9ab01f8b4db6a076223638f773684 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_efd0d22d3f54ef7e87f4a711402d7ce7.setIcon(icon_5cb9ab01f8b4db6a076223638f773684);
#
#
#         var popup_9649a0763571b19c4977c0d4abae3ec1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_eb55989c198e9e566dba0f371fe4c689 = $(`&lt;div id=&quot;html_eb55989c198e9e566dba0f371fe4c689&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Sepang International Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_9649a0763571b19c4977c0d4abae3ec1.setContent(html_eb55989c198e9e566dba0f371fe4c689);
#
#
#         marker_efd0d22d3f54ef7e87f4a711402d7ce7.bindPopup(popup_9649a0763571b19c4977c0d4abae3ec1)
#         ;
#
#
#
#
#             var marker_88aa383f61e78ac9350d6e1ad98822d2 = L.marker(
#                 [26.0325, 50.5106],
#                 {}
#             ).addTo(map_8a44d4aad0c332e191226777d5fc50f1);
#
#
#             var icon_c2fa7210021c34e6dadb0dc58c88a63c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88aa383f61e78ac9350d6e1ad98822d2.setIcon(icon_c2fa7210021c34e6dadb0dc58c88a63c);
#
#
#         var popup_7a45521ae3bbf041e768512651f4320f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0f30853217a7be8af6b0c4e2a91318eb = $(`&lt;div id=&quot;html_0f30853217a7be8af6b0c4e2a91318eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Bahrain International Circuit&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_7a45521ae3bbf041e768512651f4320f.setContent(html_0f30853217a7be8af6b0c4e2a91318eb);
#
#
#         marker_88aa383f61e78ac9350d6e1ad98822d2.bindPopup(popup_7a45521ae3bbf041e768512651f4320f)
#         ;
#
#
#
#
#             var marker_b7e971be2e62a7062f3acb77f42625a1 = L.marker(
#                 [41.57, 2.26111],
#                 {}
#             ).addTo(map_8a44d4aad0c332e191226777d5fc50f1);
#
#
#             var icon_ffcf20a158cf7d4f9b15ef0a641cba3c = L.AwesomeMarkers.icon(

# %%
df['rank'].unique()
# Out:
# array([ 2.,  3.,  6.,  5.,  4., 11.,  1., 12., 15., 10.,  9.,  8.,  7.,
#        18., 19., 13., 17.,  0., 14., 16., 20., 21., 22., 23., 24.])

# %%
df_fin = df[df['status'] == 'Finished']
df_fin.tail()
# Out:
#          resultId  racerId  driverId  constructorId  number  grid  \
# 1240921     23346      967       839            209    31.0    22
# 1240922     23346      967       839            209    31.0    22
# 1240923     23346      967       839            209    31.0    22
# 1240924     23346      967       839            209    31.0    22
# 1240925     23346      967       839            209    31.0    22
#
#          positionOrder  points  laps  timetaken_in_millisec  fastestLap  rank  \
# 1240921             12     0.0    71             10907144.0        47.0  16.0
# 1240922             12     0.0    71             10907144.0        47.0  16.0
# 1240923             12     0.0    71             10907144.0        47.0  16.0
# 1240924             12     0.0    71             10907144.0        47.0  16.0
# 1240925             12     0.0    71             10907144.0        47.0  16.0
#
#          max_speed  statusId  year  round  circuitId            grand_prix  \
# 1240921    176.686         1  2016     20         18  Brazilian Grand Prix
# 1240922    176.686         1  2016     20         18  Brazilian Grand Prix
# 1240923    176.686         1  2016     20         18  Brazilian Grand Prix
# 1240924    176.686         1  2016     20         18  Brazilian Grand Prix
# 1240925    176.686         1  2016     20         18  Brazilian Grand Prix
#
#               date driver_code        dob nationality  driverStandingsId  \
# 1240921 2016-11-13         OCO 1996-09-17      French              70668
# 1240922 2016-11-13         OCO 1996-09-17      French              70689
# 1240923 2016-11-13         OCO 1996-09-17      French              70731
# 1240924 2016-11-13         OCO 1996-09-17      French              70752
# 1240925 2016-11-13         OCO 1996-09-17      French              70770
#
#          position  wins         company    status   driver_name   age
# 1240921        11     1  Manor Marussia  Finished  Esteban Ocon  26.0
# 1240922        11     1  Manor Marussia  Finished  Esteban Ocon  26.0
# 1240923        11     1  Manor Marussia  Finished  Esteban Ocon  26.0
# 1240924        11     1  Manor Marussia  Finished  Esteban Ocon  26.0
# 1240925        10     0  Manor Marussia  Finished  Esteban Ocon  26.0

# %%
mean = df.max_speed.mean()
mean2 = df.fastestLap.mean()
df = df_fin[df_fin['max_speed']>mean]
df.head()
# Out:
#    resultId  racerId  driverId  constructorId  number  grid  positionOrder  \
# 0         1       18         1              1    22.0     1              1
# 1         1       18         1              1    22.0     1              1
# 2         1       18         1              1    22.0     1              1
# 3         1       18         1              1    22.0     1              1
# 4         1       18         1              1    22.0     1              1
#
#    points  laps  timetaken_in_millisec  fastestLap  rank  max_speed  statusId  \
# 0    10.0    58              5690616.0        39.0   2.0      218.3         1
# 1    10.0    58              5690616.0        39.0   2.0      218.3         1
# 2    10.0    58              5690616.0        39.0   2.0      218.3         1
# 3    10.0    58              5690616.0        39.0   2.0      218.3         1
# 4    10.0    58              5690616.0        39.0   2.0      218.3         1
#
#    year  round  circuitId             grand_prix       date driver_code  \
# 0  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 1  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 2  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 3  2008      1          1  Australian Grand Prix 2008-03-16         HAM
# 4  2008      1          1  Australian Grand Prix 2008-03-16         HAM
#
#          dob nationality  driverStandingsId  position  wins  company  \
# 0 1985-01-07     British                  1         1     1  McLaren
# 1 1985-01-07     British                  9         1     1  McLaren
# 2 1985-01-07     British                 27         3     1  McLaren
# 3 1985-01-07     British                 48         2     1  McLaren
# 4 1985-01-07     British                 69         3     1  McLaren
#
#      status     driver_name   age
# 0  Finished  Lewis Hamilton  37.0
# 1  Finished  Lewis Hamilton  37.0
# 2  Finished  Lewis Hamilton  37.0
# 3  Finished  Lewis Hamilton  37.0
# 4  Finished  Lewis Hamilton  37.0

# %%
df[df['fastestLap']>mean2]
# Out:
#          resultId  racerId  driverId  constructorId  number  grid  \
# 0               1       18         1              1    22.0     1
# 1               1       18         1              1    22.0     1
# 2               1       18         1              1    22.0     1
# 3               1       18         1              1    22.0     1
# 4               1       18         1              1    22.0     1
# ...           ...      ...       ...            ...     ...   ...
# 1240785     25389     1073       852            213    22.0     8
# 1240786     25389     1073       852            213    22.0     8
# 1240787     25389     1073       852            213    22.0     8
# 1240788     25389     1073       852            213    22.0     8
# 1240789     25389     1073       852            213    22.0     8
#
#          positionOrder  points  laps  timetaken_in_millisec  fastestLap  rank  \
# 0                    1    10.0    58              5690616.0        39.0   2.0
# 1                    1    10.0    58              5690616.0        39.0   2.0
# 2                    1    10.0    58              5690616.0        39.0   2.0
# 3                    1    10.0    58              5690616.0        39.0   2.0
# 4                    1    10.0    58              5690616.0        39.0   2.0
# ...                ...     ...   ...                    ...         ...   ...
# 1240785              4    12.0    58              5423037.0        50.0   7.0
# 1240786              4    12.0    58              5423037.0        50.0   7.0
# 1240787              4    12.0    58              5423037.0        50.0   7.0
# 1240788              4    12.0    58              5423037.0        50.0   7.0
# 1240789              4    12.0    58              5423037.0        50.0   7.0
#
#          max_speed  statusId  year  round  circuitId             grand_prix  \
# 0          218.300         1  2008      1          1  Australian Grand Prix
# 1          218.300         1  2008      1          1  Australian Grand Prix
# 2          218.300         1  2008      1          1  Australian Grand Prix
# 3          218.300         1  2008      1          1  Australian Grand Prix
# 4          218.300         1  2008      1          1  Australian Grand Prix
# ...            ...       ...   ...    ...        ...                    ...
# 1240785    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240786    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240787    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240788    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240789    217.285         1  2021     22         24   Abu Dhabi Grand Prix
#
#               date driver_code        dob nationality  driverStandingsId  \
# 0       2008-03-16         HAM 1985-01-07     British                  1
# 1       2008-03-16         HAM 1985-01-07     British                  9
# 2       2008-03-16         HAM 1985-01-07     British                 27
# 3       2008-03-16         HAM 1985-01-07     British                 48
# 4       2008-03-16         HAM 1985-01-07     British                 69
# ...            ...         ...        ...         ...                ...
# 1240785 2021-12-12         TSU 2000-05-11    Japanese              70664
# 1240786 2021-12-12         TSU 2000-05-11    Japanese              70685
# 1240787 2021-12-12         TSU 2000-05-11    Japanese              70727
# 1240788 2021-12-12         TSU 2000-05-11    Japanese              70748
# 1240789 2021-12-12         TSU 2000-05-11    Japanese              70777
#
#          position  wins     company    status     driver_name   age
# 0               1     1     McLaren  Finished  Lewis Hamilton  37.0
# 1               1     1     McLaren  Finished  Lewis Hamilton  37.0
# 2               3     1     McLaren  Finished  Lewis Hamilton  37.0
# 3               2     1     McLaren  Finished  Lewis Hamilton  37.0
# 4               3     1     McLaren  Finished  Lewis Hamilton  37.0
# ...           ...   ...         ...       ...             ...   ...
# 1240785        14     0  AlphaTauri  Finished    Yuki Tsunoda  22.0
# 1240786        14     0  AlphaTauri  Finished    Yuki Tsunoda  22.0
# 1240787        14     0  AlphaTauri  Finished    Yuki Tsunoda  22.0
# 1240788        14     0  AlphaTauri  Finished    Yuki Tsunoda  22.0
# 1240789        17     0  AlphaTauri  Finished    Yuki Tsunoda  22.0
#
# [397184 rows x 29 columns]

# %%
df.year.unique()
# Out:
# array([2008, 2007, 2009, 2010, 2011, 2012, 2015, 2016, 2017, 2018, 2006,
#        2005, 2004, 2013, 2014, 2021, 2019, 2020], dtype=int64)

# %%
df = df[(df['age']<df['age'].mean()) & (df['year']>2012)]
df
# Out:
#          resultId  racerId  driverId  constructorId  number  grid  \
# 170844      21722      880       815              1     6.0    15
# 170845      21722      880       815              1     6.0    15
# 170846      21722      880       815              1     6.0    15
# 170847      21722      880       815              1     6.0    15
# 170848      21722      880       815              1     6.0    15
# ...           ...      ...       ...            ...     ...   ...
# 1240785     25389     1073       852            213    22.0     8
# 1240786     25389     1073       852            213    22.0     8
# 1240787     25389     1073       852            213    22.0     8
# 1240788     25389     1073       852            213    22.0     8
# 1240789     25389     1073       852            213    22.0     8
#
#          positionOrder  points  laps  timetaken_in_millisec  fastestLap  rank  \
# 170844              11     0.0    58              5486592.0        46.0   6.0
# 170845              11     0.0    58              5486592.0        46.0   6.0
# 170846              11     0.0    58              5486592.0        46.0   6.0
# 170847              11     0.0    58              5486592.0        46.0   6.0
# 170848              11     0.0    58              5486592.0        46.0   6.0
# ...                ...     ...   ...                    ...         ...   ...
# 1240785              4    12.0    58              5423037.0        50.0   7.0
# 1240786              4    12.0    58              5423037.0        50.0   7.0
# 1240787              4    12.0    58              5423037.0        50.0   7.0
# 1240788              4    12.0    58              5423037.0        50.0   7.0
# 1240789              4    12.0    58              5423037.0        50.0   7.0
#
#          max_speed  statusId  year  round  circuitId             grand_prix  \
# 170844     212.294         1  2013      1          1  Australian Grand Prix
# 170845     212.294         1  2013      1          1  Australian Grand Prix
# 170846     212.294         1  2013      1          1  Australian Grand Prix
# 170847     212.294         1  2013      1          1  Australian Grand Prix
# 170848     212.294         1  2013      1          1  Australian Grand Prix
# ...            ...       ...   ...    ...        ...                    ...
# 1240785    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240786    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240787    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240788    217.285         1  2021     22         24   Abu Dhabi Grand Prix
# 1240789    217.285         1  2021     22         24   Abu Dhabi Grand Prix
#
#               date driver_code        dob nationality  driverStandingsId  \
# 170844  2013-03-17         PER 1990-01-26     Mexican              64406
# 170845  2013-03-17         PER 1990-01-26     Mexican              64430
# 170846  2013-03-17         PER 1990-01-26     Mexican              64454
# 170847  2013-03-17         PER 1990-01-26     Mexican              64478
# 170848  2013-03-17         PER 1990-01-26     Mexican              64502
# ...            ...         ...        ...         ...                ...
# 1240785 2021-12-12         TSU 2000-05-11    Japanese              70664
# 1240786 2021-12-12         TSU 2000-05-11    Japanese              70685
# 1240787 2021-12-12         TSU 2000-05-11    Japanese              70727
# 1240788 2021-12-12         TSU 2000-05-11    Japanese              70748
# 1240789 2021-12-12         TSU 2000-05-11    Japanese              70777
#
#          position  wins     company    status   driver_name   age
# 170844         20     0     McLaren  Finished  Sergio Pérez  32.0
# 170845         21     0     McLaren  Finished  Sergio Pérez  32.0
# 170846         18     0     McLaren  Finished  Sergio Pérez  32.0
# 170847         14     0     McLaren  Finished  Sergio Pérez  32.0
# 170848         15     0     McLaren  Finished  Sergio Pérez  32.0
# ...           ...   ...         ...       ...           ...   ...
# 1240785        14     0  AlphaTauri  Finished  Yuki Tsunoda  22.0
# 1240786        14     0  AlphaTauri  Finished  Yuki Tsunoda  22.0
# 1240787        14     0  AlphaTauri  Finished  Yuki Tsunoda  22.0
# 1240788        14     0  AlphaTauri  Finished  Yuki Tsunoda  22.0
# 1240789        17     0  AlphaTauri  Finished  Yuki Tsunoda  22.0
#
# [149740 rows x 29 columns]

# %%
df.drop('date',1,inplace=True)
df.drop('dob',1,inplace=True)
df.drop('statusId',1,inplace=True)

# %%
df.skew()
# Out:
# resultId                -0.395390
# racerId                 -0.438305
# driverId                -0.352222
# constructorId            0.569431
# number                   0.879808
# grid                     0.936669
# positionOrder            0.836671
# points                   0.200778
# laps                     0.646558
# timetaken_in_millisec    2.913383
# fastestLap              -0.186537
# rank                     0.804421
# max_speed                0.609053
# year                    -0.404904
# round                    0.017405
# circuitId                1.011411
# driverStandingsId       -3.317335
# position                 0.775866
# wins                     2.396299
# age                     -0.870737
# dtype: float64

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df = df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
df.head()
# Out:
# <ipython-input-51-df5cc41329f0>:4: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
# <ipython-input-51-df5cc41329f0>:4: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
#         resultId  racerId  driverId  constructorId  number  grid  \
# 170844     21722      880       815              1     6.0    15
# 170845     21722      880       815              1     6.0    15
# 170846     21722      880       815              1     6.0    15
# 170847     21722      880       815              1     6.0    15
# 170848     21722      880       815              1     6.0    15
#
#         positionOrder  points  laps  timetaken_in_millisec  fastestLap  rank  \
# 170844             11     0.0    58              5486592.0        46.0   6.0
# 170845             11     0.0    58              5486592.0        46.0   6.0
# 170846             11     0.0    58              5486592.0        46.0   6.0
# 170847             11     0.0    58              5486592.0        46.0   6.0
# 170848             11     0.0    58              5486592.0        46.0   6.0
#
#         max_speed  year  round  circuitId             grand_prix driver_code  \
# 170844    212.294  2013      1          1  Australian Grand Prix         PER
# 170845    212.294  2013      1          1  Australian Grand Prix         PER
# 170846    212.294  2013      1          1  Australian Grand Prix         PER
# 170847    212.294  2013      1          1  Australian Grand Prix         PER
# 170848    212.294  2013      1          1  Australian Grand Prix         PER
#
#        nationality  driverStandingsId  position  wins  company    status  \
# 170844     Mexican              64406        20     0  McLaren  Finished
# 170845     Mexican              64430        21     0  McLaren  Finished
# 170846     Mexican              64454        18     0  McLaren  Finished
# 170847     Mexican              64478        14     0  McLaren  Finished
# 170848     Mexican              64502        15     0  McLaren  Finished
#
#          driver_name   age
# 170844  Sergio Pérez  32.0
# 170845  Sergio Pérez  32.0
# 170846  Sergio Pérez  32.0
# 170847  Sergio Pérez  32.0
# 170848  Sergio Pérez  32.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(17,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
num.remove('date')
num.remove('dob')
num.remove('statusId')

# %%
plt.figure(figsize=(15,70)) 
for i,j in zip(num,range(1,len(num)+1)):
    plt.subplot(11,2,j)
    sns.kdeplot(df[i],shade=True,color='darkblue')
plt.show()

# %%
df.skew()
# Out:
# resultId                -0.299265
# racerId                 -0.339582
# driverId                -0.455516
# constructorId            0.618987
# number                   0.910108
# grid                     0.835678
# positionOrder            0.571015
# points                   0.345474
# laps                     0.563961
# timetaken_in_millisec    0.210999
# fastestLap              -0.141930
# rank                     0.658522
# max_speed                0.629596
# year                    -0.296827
# round                   -0.146136
# circuitId                1.298385
# driverStandingsId       -0.329780
# position                 0.635795
# wins                     1.800867
# age                     -0.851567
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in cat:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
# <ipython-input-58-62b198d58f8d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = le.fit_transform(df[i])
#         resultId  racerId  driverId  constructorId  number  grid  \
# 170844     21722      880       815              1     6.0    15
# 170845     21722      880       815              1     6.0    15
# 170846     21722      880       815              1     6.0    15
# 170847     21722      880       815              1     6.0    15
# 170848     21722      880       815              1     6.0    15
#
#         positionOrder  points  laps  timetaken_in_millisec  fastestLap  rank  \
# 170844             11     0.0    58              5486592.0        46.0   6.0
# 170845             11     0.0    58              5486592.0        46.0   6.0
# 170846             11     0.0    58              5486592.0        46.0   6.0
# 170847             11     0.0    58              5486592.0        46.0   6.0
# 170848             11     0.0    58              5486592.0        46.0   6.0
#
#         max_speed  year  round  circuitId  grand_prix  driver_code  \
# 170844    212.294  2013      1          1           2           19
# 170845    212.294  2013      1          1           2           19
# 170846    212.294  2013      1          1           2           19
# 170847    212.294  2013      1          1           2           19
# 170848    212.294  2013      1          1           2           19
#
#         nationality  driverStandingsId  position  wins  company  status  \
# 170844           10              64406        20     0        8       0
# 170845           10              64430        21     0        8       0
# 170846           10              64454        18     0        8       0
# 170847           10              64478        14     0        8       0
# 170848           10              64502        15     0        8       0
#
#         driver_name   age
# 170844           25  32.0
# 170845           25  32.0
# 170846           25  32.0
# 170847           25  32.0
# 170848           25  32.0

# %%
x = df.drop('driver_name',1)
y = df.driver_name

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import tree

# %%
clf = DecisionTreeClassifier(max_depth=5,random_state=1234)
clf.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=1234)

# %%
tree.export_text(clf)
# Out:
# '|--- feature_2 <= 2.00\n|   |--- class: 13\n|--- feature_2 >  2.00\n|   |--- feature_17 <= 26.50\n|   |   |--- feature_17 <= 1.50\n|   |   |   |--- feature_17 <= 0.50\n|   |   |   |   |--- class: 1\n|   |   |   |--- feature_17 >  0.50\n|   |   |   |   |--- class: 27\n|   |   |--- feature_17 >  1.50\n|   |   |   |--- feature_18 <= 0.50\n|   |   |   |   |--- class: 5\n|   |   |   |--- feature_18 >  0.50\n|   |   |   |   |--- feature_18 <= 9.50\n|   |   |   |   |   |--- class: 16\n|   |   |   |   |--- feature_18 >  9.50\n|   |   |   |   |   |--- class: 25\n|   |--- feature_17 >  26.50\n|   |   |--- class: 23\n'

# %%
fn = list(df.columns)
fn.remove('driver_name')

# %% [markdown]
# # Decision Tree

# %%
fig = plt.figure(figsize=(40,40))
_ = tree.plot_tree(clf,
               feature_names=fn,
               filled=True)

# %%
lr = LogisticRegression(solver='sag')
dt = DecisionTreeClassifier()
rn = RandomForestClassifier()
knn = KNeighborsClassifier()
gb = GaussianNB()
sgd = SGDClassifier()

# %%
li = [lr,sgd,knn,gb,rn,dt]
d = {}
for i in li:
    i.fit(xtrain,ytrain)
    ypred = i.predict(xtest)
    print(i,":",accuracy_score(ypred,ytest)*100)
    d.update({str(i):i.score(xtest,ytest)*100})
# Out:
# C:\Users\dakha\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# LogisticRegression(solver='sag') : 19.197152322548813
# SGDClassifier() : 11.12638330866286
# KNeighborsClassifier() : 100.0
# GaussianNB() : 82.02579826601819
# RandomForestClassifier() : 100.0
# DecisionTreeClassifier() : 100.0

# %%
plt.figure(figsize=(15, 6))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(d.keys(),d.values(),marker='o',color='plum',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='slategray')
plt.show()

# %% [markdown]
# As you can see, the accuracy of basic algorithm (logistic) and SGD is not good as expected. Since the data are skewed/denormalized, so it can be fixed by scaling the data.

# %% [markdown]
# # MinMaxScaler

# %% [markdown]
# Each value in a feature, MinMaxScaler subtracts the minimum value in the feature and then divides by the range. The range is the difference between the original maximum and original minimum. MinMaxScaler preserves the shape of the original distribution.

# %%
from sklearn.preprocessing import MinMaxScaler
# fit scaler on training data
norm = MinMaxScaler().fit(xtrain)
# transform training data
X_train_norm = norm.transform(xtrain)
# transform testing data
X_test_norm = norm.transform(xtest)

# %%
li = [lr,sgd,rn,knn,gb,dt]
di = {}
for i in li:
    i.fit(X_train_norm,ytrain)
    ypred = i.predict(X_test_norm)
    print(i,":",accuracy_score(ypred,ytest)*100)
    di.update({str(i):i.score(X_test_norm,ytest)*100})
# Out:
# LogisticRegression(solver='sag') : 99.99647564671884
# SGDClassifier() : 98.49510114893917
# RandomForestClassifier() : 100.0
# KNeighborsClassifier() : 100.0
# GaussianNB() : 100.0
# DecisionTreeClassifier() : 100.0

# %%
plt.figure(figsize=(15, 6))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(di.keys(),di.values(),marker='o',color='skyblue',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='black')
plt.show()

# %% [markdown]
# As you can see the accuracy are getting high for Logistic Regression and SGDClassifier, both the algorithms are performing well from bottom low to 99% accuracy by scaling. Hence this prove the importance of normalizing the data.

# %% [markdown]
# # StandardScaler

# %% [markdown]
# StandardScaler removes the mean and scales each feature/variable to unit variance. This operation is performed feature-wise in an independent way. StandardScaler can be influenced by outliers (if they exist in the dataset) since it involves the estimation of the empirical mean and standard deviation of each feature

# %%
from sklearn.preprocessing import StandardScaler
# fit scaler on training data
std = StandardScaler().fit(xtrain)
# transform train data
x_train_std = std.transform(xtrain)
# transform test data
x_test_std = std.transform(xtest)

# %%
li = [lr,sgd,rn,knn,gb,dt]
dic = {}
for i in li:
    i.fit(x_train_std,ytrain)
    ypred = i.predict(x_test_std)
    print(i,":",accuracy_score(ypred,ytest)*100)
    dic.update({str(i):i.score(x_test_std,ytest)*100})
# Out:
# C:\Users\dakha\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# LogisticRegression(solver='sag') : 100.0
# SGDClassifier() : 99.17177697892437
# RandomForestClassifier() : 100.0
# KNeighborsClassifier() : 100.0
# GaussianNB() : 100.0
# DecisionTreeClassifier() : 100.0

# %%
plt.figure(figsize=(15, 6))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(dic.keys(),dic.values(),marker='o',color='mediumpurple',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='black')
plt.show()

# %% [markdown]
# # RobustScaler

# %% [markdown]
# Scale features using statistics that are robust to outliers. This Scaler removes the median and scales the data according to the quantile range (defaults to IQR: Interquartile Range). The IQR is the range between the 1st quartile (25th quantile) and the 3rd quartile (75th quantile)

# %%
from sklearn.preprocessing import RobustScaler
# fit scaler on train data
scaler = RobustScaler().fit(xtrain)
# transform train data
xtrain_scaled = scaler.transform(xtrain)
# transform test data
xtest_scaled = scaler.transform(xtest)

# %%
li = [lr,sgd,rn,knn,gb,dt]
dics = {}
for i in li:
    i.fit(xtrain_scaled,ytrain)
    ypred = i.predict(xtest_scaled)
    print(i,":",accuracy_score(ypred,ytest)*100)
    dics.update({str(i):i.score(xtest_scaled,ytest)*100})
# Out:
# C:\Users\dakha\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# LogisticRegression(solver='sag') : 100.0
# SGDClassifier() : 99.16120391908085
# RandomForestClassifier() : 100.0
# KNeighborsClassifier() : 100.0
# GaussianNB() : 100.0
# DecisionTreeClassifier() : 100.0

# %%
plt.figure(figsize=(15, 6))
plt.title("Algorithm vs Accuracy", fontweight='bold')
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.plot(dics.keys(),dics.values(),marker='o',color='darkseagreen',linewidth=4,markersize=13,
         markerfacecolor='gold',markeredgecolor='black')
plt.show()

# %% [markdown]
# After several stages of scaling process, got a good accuracy score of 100% in all algorithms except SGDClassifier with least of 99.3% for RobustScaler. Even the least (SGDClassifier) is considered as a very good accuracy.
